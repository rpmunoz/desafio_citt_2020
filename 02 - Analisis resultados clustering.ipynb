# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("ticks")
sns.set_context("talk")

# %%
dataFile = 'data/resultado_analisis_clustering.csv'

dataDF = pd.read_csv(dataFile)
dataDF.head()
# Out:
#    ID cliente  Volumen Medio Anual  Precio Promedio por caja  Días de Retraso  \
# 0           1                15008                     18115               45
# 1           2                27294                     14232               40
# 2           3                18126                     16901               10
# 3           4                14745                     19153               15
# 4           5                11634                     17704               60
#
#    Periodos con Compra promedio  Assignments  DistancesToClusterCenter no.0  \
# 0                             6            2                       0.763175
# 1                            10            2                       0.936670
# 2                            10            0                       0.461724
# 3                            11            0                       0.341498
# 4                            11            2                       0.828749
#
# ...

# %%
NUM_CLUSTERS = 4
palette = sns.color_palette("bright", NUM_CLUSTERS)

plt.figure(figsize=(16,9))
sns.scatterplot(x='Volumen Medio Anual', y='Precio Promedio por caja', data=dataDF,
               palette=palette, hue='Assignments')

# %%
NUM_CLUSTERS = 4
palette = sns.color_palette("bright", NUM_CLUSTERS)

plt.figure(figsize=(16,9))
sns.scatterplot(x='Volumen Medio Anual', y='Días de Retraso', data=dataDF,
               palette=palette, hue='Assignments')
